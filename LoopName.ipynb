# %%
name = ''  # Initialize name with an empty string

while name != 'tu nombre':  # Continue looping until the user enters 'your name'
    print("escribi tu nombre")
    name = input()  # Take input from the user and store it in the variable 'name'

print("Eeeaaa bien ahiii!")  # This will be printed after the loop ends
